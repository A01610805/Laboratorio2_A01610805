# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("comprar_alquilar.csv")
print(df)
# Out:
#      ingresos  gastos_comunes  pago_coche  gastos_otros  ahorros  vivienda  \
# 0        6000            1000           0           600    50000    400000
# 1        6745             944         123           429    43240    636897
# 2        6455            1033          98           795    57463    321779
# 3        7098            1278          15           254    54506    660933
# 4        6167             863         223           520    41512    348932
# ..        ...             ...         ...           ...      ...       ...
# 197      3831             690         352           488    10723    363120
# 198      3961            1030         270           475    21880    280421
# 199      3184             955         276           684    35565    388025
# 200      3334             867         369           652    19985    376892
# 201      3988            1157         105           382    11980    257580
#
#      estado_civil  hijos  trabajo  comprar
# ...

# %%
plt.plot(df.ahorros, df.vivienda, '*')
plt.xlabel("Ahorros")
plt.ylabel("vivienda")
plt.show()

# %%
plt.plot(df.ingresos, df.vivienda, '*')
plt.xlabel("ingresos")
plt.ylabel("vivienda")
plt.show()

# %%
ax = sb.boxplot(x=df.trabajo, y=df.ingresos, data=df)

# %%
ax = sb.boxplot(x=df.trabajo, y=df.vivienda, data=df)

# %%
ax = sb.boxplot(x=df.hijos, y=df.vivienda, data=df)

# %%
ax = sb.boxplot(x=df.estado_civil, y=df.gastos_comunes, data=df)

# %%
ax = sb.boxplot(x=df.hijos, y=df.gastos_comunes, data=df)

# %%
#df = df.pivot("vivienda", "ingresos", "gastos_comunes")
ax = sb.heatmap(df)
